# %% [markdown]
# # Open Banking API Explorer

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/yourusername/Digital-Finance-Introduction/blob/main/day_02/notebooks/NB03_Open_Banking_API.ipynb)

# %% [markdown]
# ## Learning Objectives
#
# 1. Understand API concepts
# 2. Make mock API calls
# 3. Parse JSON responses
# 4. See how BaaS works

# %%
import requests
import json
print("Ready to explore APIs")
