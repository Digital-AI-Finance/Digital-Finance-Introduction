# %% [markdown]
# # Payment Transaction Analysis

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/yourusername/Digital-Finance-Introduction/blob/main/day_02/notebooks/NB02_Payment_Analysis.ipynb)

# %% [markdown]
# ## Learning Objectives
#
# 1. Analyze payment data
# 2. Compare fees and settlement times
# 3. Visualize payment flows

# %%
import pandas as pd
import matplotlib.pyplot as plt
print("Ready for analysis")
