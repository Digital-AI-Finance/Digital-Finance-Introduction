# %% [markdown]
# # Money and Ledgers Simulation

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/yourusername/Digital-Finance-Introduction/blob/main/day_01/notebooks/NB01_Money_Ledgers.ipynb)

# %% [markdown]
# ## Learning Objectives
#
# 1. How ledgers work
# 2. How transactions are recorded
# 3. The double-spending problem
# 4. How banks prevent it

# %% [markdown]
# ## 1. Simple Ledger

# %%
from datetime import datetime
ledger = []
balances = {"Alice": 100, "Bob": 50}
print(balances)
