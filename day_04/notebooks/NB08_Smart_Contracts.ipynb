# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/YOUR_USERNAME/Digital-Finance-Introduction/blob/main/day_04/notebooks/NB08_Smart_Contracts.ipynb)

# %% [markdown]
# # NB08: Smart Contract Interaction
#
# **Topic:** 4.1 - Smart Contracts
#
# **Learning Objectives:**
# - Understand smart contract structure
# - Interact with contracts using web3.py
# - Read and write blockchain state

# %% [markdown]
# ## 1. Setup

# %%
# !pip install -q web3
from web3 import Web3
print("Ready")
